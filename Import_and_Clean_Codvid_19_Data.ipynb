# %% [markdown]
# <a href="https://colab.research.google.com/github/mangkalapiratjr/spark/blob/main/Import_and_Clean_Codvid_19_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cleansing and Transform Covid19 cases data using PySpark**

# %% [markdown]
# **Steps**
# 1. Import Covid19 dataset (csv file from data.go.th)
# 2. Drop uninterested columns
# 3. Handle with missing values
# 4. Create a new column to group age by range
# 5. Find the wrong or inconsistent Province name in the dataset and correct them
# 6. Save output as parquet file

# %% [markdown]
# # Install libraries to use

# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/89/db/e18cfd78e408de957821ec5ca56de1250645b05f8523d169803d8df35a64/pyspark-3.1.2.tar.gz (212.4MB)
#      |████████████████████████████████| 212.4MB 66kB/s
# Collecting py4j==0.10.9
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 17.9MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.1.2-py2.py3-none-any.whl size=212880768 sha256=2c5bbd23a04cb50ce6c06cd4930a6ebe81a85e8a17771eb8569f43e30cd62b38
#   Stored in directory: /root/.cache/pip/wheels/40/1b/2c/30f43be2627857ab80062bef1527c0128f7b4070b6b2d02139
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.1.2

# %% [markdown]
# # Import libraries and create SparkSession

# %%
from pyspark.sql import  SparkSession, Row, Column
from pyspark.sql.functions import regexp_replace, col, count, when, isnan

spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # Exploring, Cleansing and Transformation of Covid19 cases data

# %%
# Import Covid19 cases data
df_covid = spark.read.csv('datasets/covid19-case.csv', header=True, inferSchema=True)

# %%
# Explore covid data
df_covid.show(5)

df_covid.summary().show()
# Out:
# +-------------+----+---+----+-----------+--------------------+-----------------+
# |announce_date| sex|age|Unit|nationality|                risk|province_of_onset|
# +-------------+----+---+----+-----------+--------------------+-----------------+
# |   12/01/2020|หญิง| 61|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|
# |   17/01/2020|หญิง| 74|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|
# |   22/01/2020|หญิง| 73|  ปี|   Thailand|คนต่างชาติเดินทาง...|           นครปฐม|
# |   22/01/2020| ชาย| 68|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|
# |   24/01/2020|หญิง| 66|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|
# +-------------+----+---+----+-----------+--------------------+-----------------+
# only showing top 5 rows
#
# +-------+-------------+------+------------------+------+-----------+--------------------+-----------------+
# |summary|announce_date|   sex|               age|  Unit|nationality|                risk|province_of_onset|
# +-------+-------------+------+------------------+------+-----------+--------------------+-----------------+
# |  count|       176515|162427|            154419|154603|     161394|              175432|           175990|
# |   mean|         null|  null| 35.09729372680823|  null|       null|                null|             null|
# | stddev|         null|  null|14.801096390839321|  null|       null|                null|             null|
# |    min|   01/01/2021|   ชาย|                 1|   วัน|Afghanistan|        ACF รองเมือง|             กทม.|
# |    25%|         null|  null|                25|  null|       null|                null|             null|
# |    50%|         null|  null|                33|  null|       null|                null|             null|
# |    75%|         null|  null|                44|  null|       null|                null|             null|
# |    max|        ระยอง|  หญิง|               100| เดือน|    ไม่ระบุ|ไปแหล่งชุมชน/สถาน...|            โคราช|
# +-------+-------------+------+------------------+------+-----------+--------------------+-----------------+

# %%
# Drop unused columns
df_covid = df_covid.drop('No.', 'Notified date', 'district_of_isolation', 'province_of_isolation', 'district_of_onset')
print(df_covid.show(5))

# Check missing values of all columns
df_covid.select( [ count( when(col(c).isNull() | isnan(col(c)), c) ).alias(c) for c in df_covid.columns]).show()
# Out:
# +-------------+----+---+----+-----------+--------------------+-----------------+
# |announce_date| sex|age|Unit|nationality|                risk|province_of_onset|
# +-------------+----+---+----+-----------+--------------------+-----------------+
# |   12/01/2020|หญิง| 61|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|
# |   17/01/2020|หญิง| 74|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|
# |   22/01/2020|หญิง| 73|  ปี|   Thailand|คนต่างชาติเดินทาง...|           นครปฐม|
# |   22/01/2020| ชาย| 68|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|
# |   24/01/2020|หญิง| 66|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|
# +-------------+----+---+----+-----------+--------------------+-----------------+
# only showing top 5 rows
#
# None
# +-------------+-----+-----+-----+-----------+----+-----------------+
# |announce_date|  sex|  age| Unit|nationality|risk|province_of_onset|
# +-------------+-----+-----+-----+-----------+----+-----------------+
# |           10|14098|22106|21922|      15131|1093|              535|
# +-------------+-----+-----+-----+-----------+----+-----------------+

# %%
# Filter only row where age and province_of_onset is not null
df_covid_filtered = df_covid.where( col('age').isNotNull() & col('Unit').isNotNull() & col('province_of_onset').isNotNull()  )

# Verified that column age and province_of_onset have no missing values
df_covid_filtered.select( [ count( when(col(c).isNull() | isnan(col(c)), c) ).alias(c) for c in df_covid.columns]).show()
# Out:
# +-------------+----+---+----+-----------+----+-----------------+
# |announce_date| sex|age|Unit|nationality|risk|province_of_onset|
# +-------------+----+---+----+-----------+----+-----------------+
# |            0|2924|  0|   0|       6974| 923|                0|
# +-------------+----+---+----+-----------+----+-----------------+

# %%
# Create a new column named age_range for grouping age by range
df_covid_group_age = df_covid_filtered.withColumn('age_range', when( (df_covid_filtered.Unit=='วัน')  | (df_covid_filtered.Unit=='เดือน')  | ( (df_covid_filtered.Unit=='ปี') & (df_covid_filtered.age <=5) )  , '0-5 ปี') 
                                                  .when( (df_covid_filtered.Unit=='ปี') & (df_covid_filtered.age >= 6) & (df_covid_filtered.age <=17) , '6-17 ปี') 
                                                  .when( (df_covid_filtered.Unit=='ปี') & (df_covid_filtered.age >= 18) & (df_covid_filtered.age <= 30), '18-30 ปี') 
                                                  .when( (df_covid_filtered.Unit=='ปี') & (df_covid_filtered.age >= 31) & (df_covid_filtered.age <= 60), '31-60 ปี') 
                                                  .otherwise('มากกว่า 60 ปี') )
df_covid_group_age.show(10)
# Out:
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+
# |announce_date| sex|age|Unit|nationality|                risk|province_of_onset|    age_range|
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+
# |   12/01/2020|หญิง| 61|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|
# |   17/01/2020|หญิง| 74|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|
# |   22/01/2020|หญิง| 73|  ปี|   Thailand|คนต่างชาติเดินทาง...|           นครปฐม|มากกว่า 60 ปี|
# |   22/01/2020| ชาย| 68|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|
# |   24/01/2020|หญิง| 66|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|มากกว่า 60 ปี|
# |   25/01/2020|หญิง| 33|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|
# |   26/01/2020|หญิง| 57|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|
# |   26/01/2020|หญิง| 73|  ปี|      China|คนต่างชาติเดินทาง...|  ประจวบคีรีขันธ์|มากกว่า 60 ปี|
# |   28/01/2020| ชาย| 63|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|
# |   28/01/2020|หญิง| 28|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|     18-30 ปี|
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+
# only showing top 10 rows

# %%
# Check Province name
df_covid_group_age.select('province_of_onset').distinct().count()
# Out:
# 81

# %%
# Since total number of Province need to be less than or equal 77, so we need to cross check with Province name list which collect in province.csv
df_province = spark.read.csv('datasets/province.csv', header=True, inferSchema=True)

# %%
# Check number of province
print(f'Total province = {df_province.distinct().count()}')

df_province.show(5)
# Out:
# Total province = 77
# +----------+--------------+----------------+--------------------+-----------------------+--------------------+-----------------------+-----------------------------------+------------------------+--------+--------------------+-------------------+---------------------+---------------------------------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------------+----------------------+----------------------------+--------------------+----------------------------------------------------+--------------------+--------------------+--------------------+-----------------+-------------------------+-----------------------------------+--------------------+----------------------+-----------------+--------------------+--------------------+------------------------+--------------------+----------------------------------+---------------------+---------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+-----------------------------+---------------------------+---------------------------+----------------------------------------------+-----------------------+-------------------------+--------------------+--------------------+------------------------+-----------------------+-------------------------+---------------------+--------------------+------------------------------+--------------------------+-----------------------------+--------------------+-------------------------+--------------------+--------------------+--------------------+-----------------------------+--------------------+--------------------+--------------------+--------------------+-----------------------+-------------------------------------------+--------------------+--------------------+-----------------------+----------------------+--------------------------+--------------------+--------------------+--------------------+
# |ProvinceNo|ProvinceMOI_ID|ProvinceNameThai|ProvinceNameThaiAbbr|ProvinceBudgetCode_2563| ProvinceNameEnglish|ProvinceOfficialWebsite|TopExecutivePositionandProvinceName|AddressforCorrespondence|RegionID|          RegionName|ProvincialClusterID|ProvincialClusterName|RegionCGDWelfareIntegrationSystem|           RegionTMD|           RegionECT|           RegionNSO|   RegionOPSIndustry|    RegionArmy|        RegionPolice|          RegionONCB|      RegionalHealth|   RegionEnvironment|     RegionRoyalRain|           RegionDGR|WaterAuthorities_ServiceArea|RegionWaterAuthorities|RegionElectricityAuthorities|           RegionLDD|RegionSecondaryEducationalServiceArea_from2010to2020|      RegionFineArts|           RegionTAT|ProvincialOffice_TAT|RegionAppealCourt|RegionAdministrativeCourt|RegionTheCriminalCourtforCorruption|          RegionPACC|RegionExciseDepartment|  RegionCGDOffice|            RegionRD|   RegionVillageFund|StateAuditRegionalOffice|           RegionPRD|RegionIndustrialRehabilitionCenter|RegionEducationOffice|RegionHealthPromotionCenter|  RegionMentalHealth|          RegionNHSO|      RegionDisaster| RegionHumanSecurity|           RegionOAE|RegionForestIndustry|RegionMilitaryCircle|           RegionDSI|           RegionDLD|  Region_CustomHouse|Region_CustomsBureau|          Region_CAD|          Region_DOA|          Region_MOI|Region_MOI_Inspection|          Region_DMR|          Region_DIP|Region_NESDC_NationalAccounts|Region_NESDC_RegionalOffice|Region_BudgetBureauDivision|RegionSecondaryEducationalServiceArea_from2021|ProvinceBudgetCode_2564|Region_InspectionArea_CPD|         Region_DOAE|Region_MonkMahaNikai|Region_MonkMahaNikai_Hon|Region_MonkDhammyuttika|Region_OPM_InspectionArea|Region_BACCDepartment|          Region_SAT|Region_OPSCulture_RoyalFuneral|Region_OPSTourismandSports|Region_TourismDevelopmentArea|          RiverBasin|Region_MOE_InspectionArea|         Region_CTCC|         Region_DMSC|          Region_DDC|Region_ThailandTrustMark_DITP|          Region_BOI|         Region_OCSB|     Region_Archives| Region_Intelligence|Region_StateAuditOffice|Region_CivicEducationandParticipationCenter|     RegionalHoliday|       Region_Forest|Region_IrrigationOffice|Region_HydrologyCenter|Region_WaterResourceOffice|         Region_DMCR| DistrictOffice_NBTC| RegionalOffice_NBTC|
# +----------+--------------+----------------+--------------------+-----------------------+--------------------+-----------------------+-----------------------------------+------------------------+--------+--------------------+-------------------+---------------------+---------------------------------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------------+----------------------+----------------------------+--------------------+----------------------------------------------------+--------------------+--------------------+--------------------+-----------------+-------------------------+-----------------------------------+--------------------+----------------------+-----------------+--------------------+--------------------+------------------------+--------------------+----------------------------------+---------------------+---------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+-----------------------------+---------------------------+---------------------------+----------------------------------------------+-----------------------+-------------------------+--------------------+--------------------+------------------------+-----------------------+-------------------------+---------------------+--------------------+------------------------------+--------------------------+-----------------------------+--------------------+-------------------------+--------------------+--------------------+--------------------+-----------------------------+--------------------+--------------------+--------------------+--------------------+-----------------------+-------------------------------------------+--------------------+--------------------+-----------------------+----------------------+--------------------------+--------------------+--------------------+--------------------+
# |         1|            10|   กรุงเทพมหานคร|                  กท|                  75002|             Bangkok|      www.bangkok.go.th|               ผู้ว่าราชการกรุงเ...|    ศาลาว่าการกรุงเทพ...|       7|            ส่วนกลาง|                 71|             ส่วนกลาง|                          ภาคกลาง|             ภาคกลาง|             ภาคกลาง|            ส่วนกลาง|            ส่วนกลาง|กองทัพภาคที่ 1|กองบัญชาการตำรวจน...|สำนักงานป้องกันแล...|เขตสุขภาพเพื่อประ...|            ส่วนกลาง|ศูนย์ปฏิบัติการฝน...|            ส่วนกลาง|             การประปานครหลวง|                   N/A|             การไฟฟ้านครหลวง|สำนักงานพัฒนาที่ด...|                                เขตพื้นที่การศึกษ...|            ส่วนกลาง|             ภาคกลาง|การท่องเที่ยวแห่ง...|       ศาลอุทธรณ์|            ศาลปกครองกลาง|               ศาลอาญาคดีทุจริตแ...|            ส่วนกลาง|  สำนักงานสรรพสามิต...|         ส่วนกลาง|สำนักงานสรรพากรภา...|            ส่วนกลาง|                ส่วนกลาง|            ส่วนกลาง|              ศูนย์ฟื้นฟูสมรรถภ...| สำนักงานศึกษาธิกา...|       สถาบันพัฒนาสุขภาว...|ศูนย์สุขภาพจิตที่ 13|สำนักงานหลักประกั...|            ส่วนกลาง|สำนักงานส่งเสริมแ...|สำนักงานเศรษฐกิจก...|องค์การอุตสาหกรรม...|    มณฑลทหารบกที่ 11|            ส่วนกลาง|            ส่วนกลาง|                 N/A|สำนักงานศุลกากรกร...|            
ภา...|สำนักงานตรวจบัญชี...|สำนักวิจัยและพัฒน...|            ภาคเหนือ|  เขตตรวจราชการที่ 18|สำนักงานทรัพยากรธ...|ศูนย์ส่งเสริมอุตส...|                     ภาคเหนือ|       สำนักงานพัฒนาเศรษ...|       กองจัดทำงบประมาณเ...|                          เขตพื้นที่การศึกษ...|                  70181|      เขตตรวจราชการที่ 18|สำนักงานส่งเสริมแ...|               ภาค 4|      เจ้าคณะใหญ่หนเหนือ|    ภาค 4 - 5 (ธรรมยุต)|      เขตตรวจราชการที่ 18| ฝ่ายกิจการสาขาภาค...|สำนักงานการกีฬาแห...|          กลุ่มอำนวยการพิธี...|                  ภาคเหนือ|         เขตพัฒนาการท่องเท...|ลุ่มน้ำปิง, ลุ่มน...|      เขตตรวจราชการที่ 18|ศูนย์ถ่ายทอดเทคโน...|ศูนย์วิทยาศาสตร์ก...|สำนักงานป้องกันคว...|                      ภาคกลาง|ศูนย์เศรษฐกิจการล...|ศูนย์ส่งเสริมอุตส...|หอจดหมายเหตุแห่งช...|ศูนย์ประสานข่าวกร...|                ภาคกลาง|                       ศูนย์ส่งเสริมการศ...|            ภาคเหนือ|สำนักจัดการทรัพยา...|   สำนักงานชลประทานท...|  ศูนย์อุทกวิทยาชลป...|      สำนักงานทรัพยากรน...|                 N/A|สำนักงานคณะกรรมกา...|สำนักงานคณะกรรมกา...|
# +----------+--------------+----------------+--------------------+-----------------------+--------------------+-----------------------+-----------------------------------+------------------------+--------+--------------------+-------------------+---------------------+---------------------------------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------------+----------------------+----------------------------+--------------------+----------------------------------------------------+--------------------+--------------------+--------------------+-----------------+-------------------------+-----------------------------------+--------------------+----------------------+-----------------+--------------------+--------------------+------------------------+--------------------+----------------------------------+---------------------+---------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------------+--------------------+--------------------+-----------------------------+---------------------------+---------------------------+----------------------------------------------+-----------------------+-------------------------+--------------------+--------------------+------------------------+-----------------------+-------------------------+---------------------+--------------------+------------------------------+--------------------------+-----------------------------+--------------------+-------------------------+--------------------+--------------------+--------------------+-----------------------------+--------------------+--------------------+--------------------+--------------------+-----------------------+-------------------------------------------+--------------------+--------------------+-----------------------+----------------------+--------------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Select only the ProvinceNameThai column, rename to Province column and remove word 'จังหวัด' from province name
df_province_name = df_province.select('ProvinceNameThai').withColumn('province', regexp_replace('ProvinceNameThai', 'จังหวัด', '')).drop('ProvinceNameThai')

# Keep province names as list
provinces =[row.province for row in df_province_name.collect()]
print( len(provinces) )
# Out:
# 77

# %%
# Find incorrect province name from Covid19 data
df_covid_group_age.select('province_of_onset').distinct().filter( ~ df_covid_group_age['province_of_onset'].isin(provinces) ).show()
# Out:
# +-----------------+
# |province_of_onset|
# +-----------------+
# |         กรุงเทพฯ|
# |            โคราช|
# |             กทม.|
# |          กรุงเทพ|
# +-----------------+

# %%
# Replace correct province name
df_covid_final = df_covid_group_age.withColumn('province',  when(( df_covid_group_age['province_of_onset']=='กรุงเทพฯ') | (df_covid_group_age['province_of_onset']=='กรุงเทพ') \
                                                                 | (df_covid_group_age['province_of_onset']=='กทม.') , 'กรุงเทพมหานคร')  \
                                                                 .when( df_covid_group_age['province_of_onset']=='โคราช', 'นครราชสีมา')
                                                                  .otherwise( df_covid_group_age['province_of_onset'])  )

# Verify that total number of province is 77
df_covid_final.select('province').distinct().count()
# Out:
# 77

# %%
# Final Output
df_covid_final.show()
# Out:
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+---------------+
# |announce_date| sex|age|Unit|nationality|                risk|province_of_onset|    age_range|       province|
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+---------------+
# |   12/01/2020|หญิง| 61|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   17/01/2020|หญิง| 74|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   22/01/2020|หญิง| 73|  ปี|   Thailand|คนต่างชาติเดินทาง...|           นครปฐม|มากกว่า 60 ปี|         นครปฐม|
# |   22/01/2020| ชาย| 68|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   24/01/2020|หญิง| 66|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|มากกว่า 60 ปี|        นนทบุรี|
# |   25/01/2020|หญิง| 33|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   26/01/2020|หญิง| 57|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   26/01/2020|หญิง| 73|  ปี|      China|คนต่างชาติเดินทาง...|  ประจวบคีรีขันธ์|มากกว่า 60 ปี|ประจวบคีรีขันธ์|
# |   28/01/2020| ชาย| 63|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   28/01/2020|หญิง| 28|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|     18-30 ปี|        นนทบุรี|
# |   28/01/2020| ชาย| 33|  ปี|      China|สัมผัสใกล้ชิดกับผ...|         กรุงเทพฯ|     31-60 ปี|  กรุงเทพมหานคร|
# |   28/01/2020| ชาย| 61|  ปี|      China|สัมผัสใกล้ชิดกับผ...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   28/01/2020| ชาย|  6|  ปี|      China|สัมผัสใกล้ชิดกับผ...|    กรุงเทพมหานคร|      6-17 ปี|  กรุงเทพมหานคร|
# |   28/01/2020|หญิง| 32|  ปี|      China|คนต่างชาติเดินทาง...|           ภูเก็ต|     31-60 ปี|         ภูเก็ต|
# |   31/01/2020| ชาย| 56|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   31/01/2020| ชาย| 50|  ปี|   Thailand|อาชีพเสี่ยง เช่น ...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   31/01/2020| ชาย| 28|  ปี|      China|คนต่างชาติเดินทาง...|        เชียงใหม่|     18-30 ปี|      เชียงใหม่|
# |   31/01/2020| ชาย| 30|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     18-30 ปี|  กรุงเทพมหานคร|
# |   31/01/2020| ชาย| 33|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   04/02/2020|หญิง| 43|  ปี|   Thailand|คนไทยเดินทางกลับจ...|         กรุงเทพฯ|     31-60 ปี|  กรุงเทพมหานคร|
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+---------------+
# only showing top 20 rows

# %%
# Save DataFrame to Parquet File
df_covid_final.write.parquet('output', mode='overwrite')

# %%
# Test Output File
df = spark.read.parquet('output')
df.show()
# Out:
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+---------------+
# |announce_date| sex|age|Unit|nationality|                risk|province_of_onset|    age_range|       province|
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+---------------+
# |   12/01/2020|หญิง| 61|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   17/01/2020|หญิง| 74|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   22/01/2020|หญิง| 73|  ปี|   Thailand|คนต่างชาติเดินทาง...|           นครปฐม|มากกว่า 60 ปี|         นครปฐม|
# |   22/01/2020| ชาย| 68|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   24/01/2020|หญิง| 66|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|มากกว่า 60 ปี|        นนทบุรี|
# |   25/01/2020|หญิง| 33|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   26/01/2020|หญิง| 57|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   26/01/2020|หญิง| 73|  ปี|      China|คนต่างชาติเดินทาง...|  ประจวบคีรีขันธ์|มากกว่า 60 ปี|ประจวบคีรีขันธ์|
# |   28/01/2020| ชาย| 63|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   28/01/2020|หญิง| 28|  ปี|      China|คนต่างชาติเดินทาง...|          นนทบุรี|     18-30 ปี|        นนทบุรี|
# |   28/01/2020| ชาย| 33|  ปี|      China|สัมผัสใกล้ชิดกับผ...|         กรุงเทพฯ|     31-60 ปี|  กรุงเทพมหานคร|
# |   28/01/2020| ชาย| 61|  ปี|      China|สัมผัสใกล้ชิดกับผ...|    กรุงเทพมหานคร|มากกว่า 60 ปี|  กรุงเทพมหานคร|
# |   28/01/2020| ชาย|  6|  ปี|      China|สัมผัสใกล้ชิดกับผ...|    กรุงเทพมหานคร|      6-17 ปี|  กรุงเทพมหานคร|
# |   28/01/2020|หญิง| 32|  ปี|      China|คนต่างชาติเดินทาง...|           ภูเก็ต|     31-60 ปี|         ภูเก็ต|
# |   31/01/2020| ชาย| 56|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   31/01/2020| ชาย| 50|  ปี|   Thailand|อาชีพเสี่ยง เช่น ...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   31/01/2020| ชาย| 28|  ปี|      China|คนต่างชาติเดินทาง...|        เชียงใหม่|     18-30 ปี|      เชียงใหม่|
# |   31/01/2020| ชาย| 30|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     18-30 ปี|  กรุงเทพมหานคร|
# |   31/01/2020| ชาย| 33|  ปี|      China|คนต่างชาติเดินทาง...|    กรุงเทพมหานคร|     31-60 ปี|  กรุงเทพมหานคร|
# |   04/02/2020|หญิง| 43|  ปี|   Thailand|คนไทยเดินทางกลับจ...|         กรุงเทพฯ|     31-60 ปี|  กรุงเทพมหานคร|
# +-------------+----+---+----+-----------+--------------------+-----------------+-------------+---------------+
# only showing top 20 rows
